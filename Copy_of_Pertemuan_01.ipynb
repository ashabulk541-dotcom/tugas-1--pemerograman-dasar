# %% [markdown]
# <a href="https://colab.research.google.com/github/ashabulk541-dotcom/tugas-1--pemerograman-dasar/blob/main/Copy_of_Pertemuan_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya
nama = "Kahfi"
umur = 26
jurusan = "RPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
status_lulus = False

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Kahfi
# 26
# RPE
# 3
# Pemerograman Dasar
# False
